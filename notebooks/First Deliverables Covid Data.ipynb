# %% [markdown]
# # Enterprise Data Science Exercise 1 & 2
#
# ## Maxwell Bald (415680) SS22

# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# ### Import and Organize Data

# %%
    #Saved file from https://covid.ourworldindata.org/data/owid-covid-data.csv in Notebook folder
    data = pd.read_csv("owid-covid-data.csv",sep=',')
    
    #Add column of cases by population
    data['cases_per_pop']=data['total_cases']/data['population']
    #Add column of vaccinations by population (Fully Vaccinated)
    data['vaxd_per_pop']=data['people_fully_vaccinated']/data['population']
    
    #Separate Out Individual Countries
    data_de = data[data['location']=='Germany']
    data_de = data_de.reset_index(drop=True)

    data_fr = data[data['location']=='France']
    data_fr = data_fr.reset_index(drop=True)

    data_uk = data[data['location']=='United Kingdom']
    data_uk = data_uk.reset_index(drop=True)
    
    #Create a combined dataframe of selected countries for plotting
    
    data_comb = pd.concat([data_de,data_fr,data_uk])

# %% [markdown]
# ### Create Plot of Covid Cases

# %%
   
    fig_cases = px.line(data_comb,x="date",y="cases_per_pop", color='location', title= 'COVID-19 Cases by Population', 
                        labels={"date":"Date","cases_per_pop":"Cases per Capita","location":"Country Name"})
    fig_cases.show()
# Out:
# <div>                            <div id="5d13bd12-e1f5-47b0-ae63-e577c400d26b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d13bd12-e1f5-47b0-ae63-e577c400d26b")) {                    Plotly.newPlot(                        "5d13bd12-e1f5-47b0-ae63-e577c400d26b",                        [{"hovertemplate":"Country Name=Germany<br>Date=%{x}<br>Cases per Capita=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","20
# ...

# %% [markdown]
# ### Create Plot of Vaccination by Population

# %%
  
    fig_vax = px.line(data_comb,x="date",y="vaxd_per_pop", color='location', title= 'COVID-19 Vaccinations by Population', 
                      labels={"date":"Date","vaxd_per_pop":"Full Vaccinations per Capita","location":"Country Name"},range_x=['2021-01-01','2022-06-20'])
    fig_vax.show()
# Out:
# <div>                            <div id="46f97c2a-07a4-49ea-b503-f4115cff25de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46f97c2a-07a4-49ea-b503-f4115cff25de")) {                    Plotly.newPlot(                        "46f97c2a-07a4-49ea-b503-f4115cff25de",                        [{"hovertemplate":"Country Name=Germany<br>Date=%{x}<br>Full Vaccinations per Capita=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","202
# ...
